# %%
import pandas as pd

ventas_df = pd.read_csv("ventas.csv")
ventas_df.head()
# Out:
#    id_venta       fecha  producto  cantidad  precio_unitario
# 0         1  2026-01-10  Notebook         2             1200
# 1         2  2026-01-12     Mouse         5               25
# 2         3  2026-01-15   Teclado         3               45
# 3         4  2026-01-18   Monitor         1              300

# %%
clientes_df = pd.read_json("clientes.json")

total_clientes = len(clientes_df)
print("Cantidad total de clientes:", total_clientes)
# Out:
# Cantidad total de clientes: 3

# %%
inventario_df = pd.read_excel("inventario.xlsx")


promedio_stock = inventario_df["stock"].mean()
print("Promedio de stock disponible:", promedio_stock)
# Out:
# Promedio de stock disponible: 26.25
